# %% [markdown]
# # Attention Seeker Demo Notebook
# Lightweight execution for project demo.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('attention_scores.csv')
df.head()

# %%
plt.scatter(df['attention_score'], df['outside_factors'])
plt.title('Attention Score vs Outside Factors')
plt.show()

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
train.shape, test.shape
